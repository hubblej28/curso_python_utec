# %% [markdown]
# <a href="https://colab.research.google.com/github/hubblej28/curso_python_utec/blob/main/Laboratorios/Modulo_3/Sesi%C3%B3n_4_Ejemplos_%2B_Datosaurus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1KaUW3_JAieeY7WVNfoRiTSr2JsaeAcXi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **<font color='lightcoral'>Módulo 3 - Sesión 4 - Ejemplos + Datosaurus</font>**
# ## <font color='#80b1d3'> Profesor: Germain García Zanabria</font>
#
#
#
# ---

# %% [markdown]
# # **Matplotlib**
# ![picture](https://matplotlib.org/stable/_static/logo_light.svg)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='--', color='#80b1d3', label='Crecimiento') # '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

plt.xlabel('Días')  # Etiqueta del eje X
plt.ylabel('Valores')  # Etiqueta del eje Y
plt.title('Ejemplo de Gráfico de Líneas')  # Título del gráfico
plt.legend()  # Mostrar leyenda
# Añadir líneas de la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Función Cuadrática

# %%
import numpy as np

# Parámetros de la función cuadrática
#datos
a, b, c = 1, -3, 2
x = np.linspace(-10, 10, 100)
y = a * x**2 + b * x + c





plt.plot(x, y,linestyle='--',color='#80b1d3')


plt.title('Función Cuadrática')

plt.xlabel('Eje x')
plt.ylabel('Eje y')


plt.grid(True)
plt.show() # cierre

# %% [markdown]
# # Función de Equilibrio de Mercado

# %%
import matplotlib.pyplot as plt
import numpy as np

# Oferta y demanda
x = np.linspace(0, 10, 100)
oferta = 2 * x + 5
demanda = -3 * x + 40

# %%
plt.plot(x, oferta, color ='r', label='Oferta')
plt.plot(x, demanda, color ='b', label='Demanda')


plt.title('Función de Equilibrio de Mercado')
plt.xlabel('Cantidad')
plt.ylabel('Precio')

plt.axvline(7, color='green', linestyle='--')
plt.axhline(19, color='g', linestyle='--')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Algo más allá
#
# Vamos a intentar ver ventas

# %%
import pandas as pd
np.random.seed(42)


fechas = pd.date_range(start="2024-01-01", periods=100, freq="D") # Fechas diarias (100 días)


serie_a = np.cumsum(np.random.randn(100)) + 50
serie_b = np.cumsum(np.random.randn(100)) + 40

df = pd.DataFrame({
    "Fecha": fechas,
    "Serie A": serie_a,
    "Serie B": serie_b
})

# %%
df.head()
# Out:
#        Fecha    Serie A    Serie B
# 0 2024-01-01  50.496714  38.584629
# 1 2024-01-02  50.358450  38.163984
# 2 2024-01-03  51.006138  37.821269
# 3 2024-01-04  52.529168  37.018992
# 4 2024-01-05  52.295015  36.857706

# %%
plt.figure(figsize=(10, 5))

plt.plot(df["Fecha"], df["Serie A"], label="Ventas de A")
plt.plot(df["Fecha"], df["Serie B"], label="Ventas de B")

plt.xlabel("Fecha")
plt.ylabel("ventas")
plt.title("Series temporales de ventas")
plt.grid(linestyle='--',color='#bebada',linewidth=0.5) ##plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.legend()

plt.xticks(rotation=45)
plt.yticks(rotation=45)
#plt.tight_layout()
plt.show()

# %%
import pandas as pd
df_covid = pd.read_csv("https://github.com/germaingarcia/Files_Lectures/raw/refs/heads/main/PythonProgram/fallecidos_covid.csv", encoding='latin-1')

# %%
df_covid.drop(columns=['UUID','FECHA_NAC'],inplace=True)
df_covid['FECHA_FALLECIMIENTO'] = pd.to_datetime(df_covid['FECHA_FALLECIMIENTO'], format='%Y%m%d', errors='coerce')
fallecidos_por_fecha = df_covid.groupby('FECHA_FALLECIMIENTO').size().reset_index(name='numero')

# %%
# completa aquí, muestra la evolución de fallecidos
x = fallecidos_por_fecha['FECHA_FALLECIMIENTO']
y = fallecidos_por_fecha['numero']
plt.figure(figsize=(20,5))
plt.plot(x,y, marker = 'o', linestyle = '--', color='#80b1d3', label = 'Crecimiento')

plt.title('Evolucion de fallecidos Covid')
plt.xlabel('fecha')
plt.ylabel('cantidad de fallecidos')
plt.axvline(pd.to_datetime('2020-04-01'), color='green', linestyle='--', label='Abril 2020')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # Función de Costo Marginal
# El Costo Marginal (MC, por sus siglas en inglés de "Marginal Cost") es una herramienta económica que mide el cambio en el costo total de producción cuando se produce una unidad adicional de un bien o servicio. Es una función fundamental en la teoría de la producción y se utiliza para optimizar las decisiones de producción y fijación de precios.
#
#
# Una forma común es
# 𝑀𝐶(𝑄)= 𝑐 + 𝑑 𝑄

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parámetros de la función de costo marginal
c, d = 10, 2
Q = np.linspace(0, 10, 100)
MC = c + d * Q

plt.plot(Q, MC)
plt.title('Función de Costo Marginal')
plt.xlabel('Cantidad Producida (Q)')
plt.ylabel('Costo Marginal (MC)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Subplots

# %%
#import matplotlib.pyplot as plt
#import numpy as np

# Crear valores de x
x = np.linspace(-10, 10, 400)

# Definir las funciones lineales
y1 = 2 * x + 1
y2 = -x + 3
y3 = 0.5 * x *x - 2
y4 = 3 * x + 4

# Crear una figura con 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Función Lineal 1
axs[0, 0].plot(x, y1, 'b-')
axs[0, 0].set_title('y = 2x + 1')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].grid(True)

# Función Lineal 2
axs[0, 1].plot(x, y2, 'r-')
axs[0, 1].set_title('y = -x + 3')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].grid(True)

# Función Lineal 3
axs[1, 0].plot(x, y3, 'g-')
axs[1, 0].set_title('y = 0.5x*x - 2')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].grid(True)

# Función Lineal 4
axs[1, 1].plot(x, y4, 'm-')
axs[1, 1].set_title('y = 3x + 4')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].grid(True)

# Ajustar el layout para evitar superposiciones
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Gráfico de Dispersión

# %%
# Simular datos de horas de estudio y calificaciones
np.random.seed(0)

horas_estudio = np.random.randint(1, 10, 50) #x
calificaciones = horas_estudio * 10 + np.random.normal(0, 5, 50) # y

# Crear un DataFrame con los datos
data = {
    'Horas de Estudio': horas_estudio,
    'Calificaciones': calificaciones
}
df = pd.DataFrame(data)
df.head()

# %%
# Crear una figura
plt.figure(figsize=(8, 4))

# Crear el gráfico de dispersión
plt.scatter(df['Horas de Estudio'], df['Calificaciones'], color='b', marker='x')

# Añadir título y etiquetas de los ejes
plt.title('Relación entre Horas de Estudio y Calificaciones')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')

# Añadir una cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Gráfico Histograma

# %%
import matplotlib.pyplot as plt
import numpy as np

# (calificaciones de estudiantes)
np.random.seed(42)
calificaciones = np.random.normal(15, 5, 100)  # Media = 70, Desviación estándar = 10, Número de datos = 100
calificaciones

# %%
# Crear una figura
plt.figure(figsize=(10, 6))


# Crear el histograma
plt.hist(calificaciones, bins=30, edgecolor='gray')

# Añadir título y etiquetas de los ejes
#plt.title('Distribución de Calificaciones de Estudiantes')
#plt.xlabel('Calificaciones')
#plt.ylabel('Frecuencia')

#plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
# Sacar un histograma con Edad declarada de Df covid

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

np.random.seed(42)

datos = {
    'Matematicas': np.random.normal(70, 10, 100),
    'Ciencias': np.random.normal(65, 15, 100),
    'Ingles': np.random.normal(75, 12, 100)
}

df = pd.DataFrame(datos)
df.head()

# %%
plt.figure(figsize=(10, 6))

data_to_plot = [df['Matematicas'], df['Ciencias'],df['Ingles']]



plt.boxplot(data_to_plot, labels=['Matemáticas', 'Ciencias','Ingles'])

# Añadir título y etiquetas de los ejes
plt.title('Distribución de Calificaciones por Asignatura')
plt.xlabel('Asignatura')
plt.ylabel('Calificaciones')
plt.grid(True)
plt.show()

# %% [markdown]
# # Datosaurus
# Es un conjunto de datos creado para ilustrar la importancia de visualizar los datos en lugar de confiar únicamente en las estadísticas resumidas. El conjunto de datos original, conocido como "Datasaurus," fue diseñado para demostrar que diferentes conjuntos de datos pueden tener las mismas estadísticas descriptivas (media, varianza, correlación, etc.) pero pueden ser muy diferentes cuando se visualizan gráficamente.

# %%
PATH = 'https://raw.githubusercontent.com/germaingarcia/Files_Lectures/main/Datasaurus_data.csv'

# %%
from IPython.display import display
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# Lee el archivo .csv
df = pd.read_csv(PATH)

# Muestra las primeras filas del DataFrame para verificar que se haya cargado correctamente
df

# %%
df_dino = df[df['dataset']=='dino']
df_dino

# %%
df_dino = df[df['dataset']=='dino']
plt.scatter(df_dino['x'], df_dino['y'], color='#fb8072', marker='x',edgecolor='gray')

#plt.grid(True)
plt.show()

# %%
datasets = df['dataset'].unique()
datasets

# %% [markdown]
# ##  1. Cargar y visualizar el conjunto de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(df.head())

datasets = df['dataset'].unique()

# Crear la figura y los subplots
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(14, 10))
axes = axes.flatten()

# Mapear los datos en cada subplot
for i, dataset in enumerate(datasets):
    subset = df[df['dataset'] == dataset]
    axes[i].scatter(subset['x'], subset['y'], color='red', marker='o',edgecolor='white')
    axes[i].set_title(dataset)
    axes[i].set_xlabel('x')
    axes[i].set_ylabel('y')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Ajustar el título
fig.suptitle('Datasaurus Dozen: Conjuntos de Datos Diferentes con Estadísticas Resumidas Idénticas', fontsize=16)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ##  2. Histograms for the x and y coordinates for one of the datasets:

# %%
dino_data = df[df['dataset'] == 'dino']


fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Histograma para los valores de 'x'
axes[0].hist(dino_data['x'], bins=10, color='green',edgecolor='white')
axes[0].set_title('Histogram of x values for dino dataset')
axes[0].set_xlabel('x values')
axes[0].set_ylabel('Frequency')

# Histograma para los valores de 'y'
axes[1].hist(dino_data['y'], bins=10, edgecolor='black')
axes[1].set_title('Histogram of y values for dino dataset')
axes[1].set_xlabel('y values')
axes[1].set_ylabel('Frequency')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 3. Subplots para comparar diagramas de dispersión de algunos conjuntos de datos uno al lado del otro

# %%
datasets = ['dino', 'dots', 'x_shape']

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for ax, dataset in zip(axes, datasets):
    data = df[df['dataset'] == dataset]
    ax.scatter(data['x'], data['y'])
    ax.set_title(f'Scatter plot para {dataset}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 4. Box plot para todas las variables X de los diferentes datasets:

# %%
data_to_plot = [df[df['dataset'] == dataset]['x'] for dataset in datasets]

# %%
# Crear un box plot de la variable 'x' para todos los datasets
plt.figure(figsize=(12, 6))
datasets = df['dataset'].unique()

# Crear una lista de listas para los datos de 'x'
data_to_plot = [df[df['dataset'] == dataset]['x'] for dataset in datasets]

plt.boxplot(data_to_plot, labels=datasets,patch_artist=True)

plt.title('Box Plot de la Variable X en Todos los Datasets')
plt.xlabel('Dataset')
plt.ylabel('X')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## 5. Box plot para todas las variables Y de los diferentes datasets:

# %%
# Crear un box plot de la variable 'y' para todos los datasets

plt.figure(figsize=(12, 6))

datasets = df['dataset'].unique()
data = [df.loc[df['dataset'] == d, 'y'].values for d in datasets]

#sns.boxplot(x='dataset', y='y', data=df)
plt.boxplot(data, labels=datasets)
plt.title('Box Plot de la Variable Y en Todos los Datasets')
plt.xlabel('Dataset')
plt.ylabel('Y')
plt.xticks(rotation=45)
plt.show()
